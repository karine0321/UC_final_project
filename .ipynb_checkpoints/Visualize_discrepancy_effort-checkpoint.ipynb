# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import geoplot
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
import numpy as np

data_path = r'.\data\abbreviation.csv'
abbr = pd.read_csv(data_path)
data_path = r'.\data\discr_eff\discr_eff_val.csv'
data = pd.read_csv(data_path)
data = data.set_index('STATE') # (48, 7)
abbr = abbr.set_index('State') # (51, 2)
result = pd.concat([data, abbr], axis=1, join='inner') #(48, 9)
#result.to_csv('abbr_de.csv')
#new = result[['Code','bed_covid_discrepancy']]

# %% [markdown]
# bed_covid

# %%
plt.style.use('default')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter
f = plt.figure(figsize=(10,8))
ax = result['bed_covid_discrepancy'].plot(kind='barh', figsize=(8, 10), color='#86bf91', zorder=2, width=0.85)
# plt.barh(result['Code'],result['bed_covid_discrepancy'])
ax=plt.subplot()
ax.invert_yaxis()

# Despine
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)

# Switch off ticks
ax.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")

# Draw vertical axis lines
vals = ax.get_xticks()
for tick in vals:
  ax.axvline(x=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

# Set x-axis label
ax.set_xlabel("bed_covid_discrepancy", labelpad=20, weight='bold', size=12)

# Set y-axis label
ax.set_ylabel("State", labelpad=20, weight='bold', size=12)

# Format y-axis label
ax.xaxis.set_major_formatter(StrMethodFormatter('{x:,g}'))

plt.savefig('pic2/bed_covid_discrepancy.png')
# Out:
# C:\Users\13010\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   if __name__ == '__main__':

# %%
plt.style.use('default')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter
f = plt.figure(figsize=(10,8))
ax = result['bed_covid_effort'].plot(kind='barh', figsize=(8, 10), color='#cfaf9c', zorder=2, width=0.85)
# plt.barh(result['Code'],result['bed_covid_discrepancy'])
ax=plt.subplot()
ax.invert_yaxis()

# Despine
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)

# Switch off ticks
ax.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")

# Draw vertical axis lines
vals = ax.get_xticks()
for tick in vals:
  ax.axvline(x=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

# Set x-axis label
ax.set_xlabel("bed_covid_effort", labelpad=20, weight='bold', size=12)

# Set y-axis label
ax.set_ylabel("State", labelpad=20, weight='bold', size=12)

# Format y-axis label
ax.xaxis.set_major_formatter(StrMethodFormatter('{x:,g}'))

plt.savefig('pic2/bed_covid_effort.png')
# Out:
# C:\Users\13010\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   if __name__ == '__main__':

# %% [markdown]
# bed_pop

# %%
plt.style.use('default')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter
f = plt.figure(figsize=(10,8))
ax = result['bed_pop_discrepancy'].plot(kind='barh', figsize=(8, 10), color='#86bf91', zorder=2, width=0.85)
# plt.barh(result['Code'],result['bed_covid_discrepancy'])
ax=plt.subplot()
ax.invert_yaxis()

# Despine
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)

# Switch off ticks
ax.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")

# Draw vertical axis lines
vals = ax.get_xticks()
for tick in vals:
  ax.axvline(x=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

# Set x-axis label
ax.set_xlabel("bed_pop_discrepancy", labelpad=20, weight='bold', size=12)

# Set y-axis label
ax.set_ylabel("State", labelpad=20, weight='bold', size=12)

# Format y-axis label
ax.xaxis.set_major_formatter(StrMethodFormatter('{x:,g}'))

plt.savefig('pic2/bed_pop_discrepancy.png')
# Out:
# C:\Users\13010\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   if __name__ == '__main__':

# %%
plt.style.use('default')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter
f = plt.figure(figsize=(10,8))
ax = result['bed_pop_effort'].plot(kind='barh', figsize=(8, 10), color='#cfaf9c', zorder=2, width=0.85)
# plt.barh(result['Code'],result['bed_covid_discrepancy'])
ax=plt.subplot()
ax.invert_yaxis()

# Despine
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)

# Switch off ticks
ax.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")

# Draw vertical axis lines
vals = ax.get_xticks()
for tick in vals:
  ax.axvline(x=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

# Set x-axis label
ax.set_xlabel("bed_pop_discrepancy", labelpad=20, weight='bold', size=12)

# Set y-axis label
ax.set_ylabel("State", labelpad=20, weight='bold', size=12)

# Format y-axis label
ax.xaxis.set_major_formatter(StrMethodFormatter('{x:,g}'))

plt.savefig('pic2/bed_pop_effort.png')
# Out:
# C:\Users\13010\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   if __name__ == '__main__':

# %% [markdown]
# bed_true_pred

# %%
data_path = r'.\estireal-de.csv'
result_realpre = pd.read_csv(data_path)
result_realpre = result_realpre.set_index('Unnamed: 0')
result_realpre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49 entries, Alabama to Wyoming
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   effort       49 non-null     float64
#  1   discrepancy  49 non-null     float64
# dtypes: float64(2)
# memory usage: 1.1+ KB

# %%
plt.style.use('default')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter
f = plt.figure(figsize=(10,8))
ax = result_realpre['discrepancy'].plot(kind='barh', figsize=(8, 10), color='#86bf91', zorder=2, width=0.85)
# plt.barh(result['Code'],result['bed_covid_discrepancy'])
ax=plt.subplot()
ax.invert_yaxis()

# Despine
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)

# Switch off ticks
ax.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")

# Draw vertical axis lines
vals = ax.get_xticks()
for tick in vals:
  ax.axvline(x=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

# Set x-axis label
ax.set_xlabel("bed_true_estimate_discrepancy", labelpad=20, weight='bold', size=12)

# Set y-axis label
ax.set_ylabel("State", labelpad=20, weight='bold', size=12)

# Format y-axis label
ax.xaxis.set_major_formatter(StrMethodFormatter('{x:,g}'))

plt.savefig('pic2/bed_true_pred_discrepancy.png')
# Out:
# C:\Users\13010\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   if __name__ == '__main__':

# %%
plt.style.use('default')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter
f = plt.figure(figsize=(10,8))
ax = result_realpre['effort'].plot(kind='barh', figsize=(8, 10), color='#cfaf9c', zorder=2, width=0.85)
# plt.barh(result['Code'],result['bed_covid_discrepancy'])
ax=plt.subplot()
ax.invert_yaxis()

# Despine
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)

# Switch off ticks
ax.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")

# Draw vertical axis lines
vals = ax.get_xticks()
for tick in vals:
  ax.axvline(x=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

# Set x-axis label
ax.set_xlabel("bed_true_estimate_effort", labelpad=20, weight='bold', size=12)

# Set y-axis label
ax.set_ylabel("State", labelpad=20, weight='bold', size=12)

# Format y-axis label
ax.xaxis.set_major_formatter(StrMethodFormatter('{x:,g}'))

plt.savefig('pic2/bed_true_pred_effort.png')
# Out:
# C:\Users\13010\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   if __name__ == '__main__':
